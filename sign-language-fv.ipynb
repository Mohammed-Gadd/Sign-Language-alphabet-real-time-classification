# %%
import matplotlib.pyplot as plt
import numpy as np
import tensorflow as tf
from tensorflow.keras import layers
import tensorflow as tf
from tensorflow import keras
import numpy as np
import os, keras
import cv2

# %%
SIZE = 64
BATCH_SIZE = 128

# %%
train_dir = "sl_alphabet/asl_alphabet_train"
train_ds = tf.keras.preprocessing.image_dataset_from_directory(
    train_dir,
    validation_split=0.2,  
    subset="training",     
    seed=123,              
    image_size=(SIZE,SIZE), 
    batch_size=BATCH_SIZE,  
    color_mode='rgb',
    label_mode='categorical'
)
# Out:
# Found 87000 files belonging to 1 classes.
# Using 69600 files for training.

# %%
val_ds = tf.keras.preprocessing.image_dataset_from_directory(
    train_dir,
    validation_split=0.2,
    subset="validation",   
    seed=123,             
    image_size=(SIZE,SIZE),
    batch_size=BATCH_SIZE,        
    color_mode='rgb',
    label_mode='categorical'
)
# Out:
# Found 87000 files belonging to 1 classes.
# Using 17400 files for validation.

# %%
test_dir = 'sl_alphabet/asl_alphabet_test'
test_ds = tf.keras.preprocessing.image_dataset_from_directory(
    test_dir,  
    seed=123,     
    batch_size=BATCH_SIZE,        
    image_size=(SIZE,SIZE),         
    color_mode='rgb',
    label_mode='categorical',
    shuffle = False
)
# Out:
# Found 28 files belonging to 1 classes.

# %%
model = tf.keras.models.Sequential([
    
    # Rescale images to the range [0, 1]
    tf.keras.layers.Rescaling(1./255, input_shape=(SIZE, SIZE, 3)),

    # Convolutional layers with ReLU activation and MaxPooling
    tf.keras.layers.Conv2D(filters=64, kernel_size=(3,3), activation='relu'),
    tf.keras.layers.MaxPooling2D(pool_size=2),

    tf.keras.layers.Conv2D(filters=32, kernel_size=(3,3), activation='relu'),
    tf.keras.layers.MaxPooling2D(pool_size=2),

    tf.keras.layers.Conv2D(filters=16, kernel_size=(3,3), activation='relu'),
    tf.keras.layers.MaxPooling2D(pool_size=2),
    tf.keras.layers.BatchNormalization(),
    # Flattening the output from the convolutional layers
    tf.keras.layers.Flatten(),

    # Dense layers
    tf.keras.layers.Dense(units=64, activation='relu'),
    tf.keras.layers.Dense(units=32, activation='relu'),
    tf.keras.layers.BatchNormalization(),
    tf.keras.layers.Dropout(0.2),
    # Output layer with softmax activation (for 29 classes)
    tf.keras.layers.Dense(units=29, activation='softmax')
])

# %%
base_learning_rate = 0.001
model.compile(optimizer=tf.keras.optimizers.Adam(learning_rate=base_learning_rate),
              loss=tf.keras.losses.CategoricalCrossentropy (),
              metrics=['accuracy'])

# %%
history = model.fit(
  train_ds,
  validation_data=val_ds,
  epochs=10
)
# Out:
# Epoch 1/10
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# I0000 00:00:1724438449.946005     158 service.cc:145] XLA service 0x7efab4004b20 initialized for platform CUDA (this does not guarantee that XLA will be used). Devices:
# I0000 00:00:1724438449.946063     158 service.cc:153]   StreamExecutor device (0): Tesla T4, Compute Capability 7.5
# I0000 00:00:1724438449.946073     158 service.cc:153]   StreamExecutor device (1): Tesla T4, Compute Capability 7.5
#   4/544 ━━━━━━━━━━━━━━━━━━━━ 10s 19ms/step - accuracy: 0.0306 - loss: 3.9373
# I0000 00:00:1724438455.534490     158 device_compiler.h:188] Compiled cluster using XLA!  This line is logged at most once for the lifetime of the process.
# 544/544 ━━━━━━━━━━━━━━━━━━━━ 119s 204ms/step - accuracy: 0.2641 - loss: 2.6520 - val_accuracy: 0.4822 - val_loss: 1.5868
# Epoch 2/10
# ...

# %%
model.save('model_3.h5')

# %%
test_loss, test_acc = model.evaluate(val_ds)
# Out:
# 136/136 ━━━━━━━━━━━━━━━━━━━━ 7s 48ms/step - accuracy: 0.9801 - loss: 0.0587

# %%
test_acc
# Out:
# 0.9796551465988159

# %%
test_loss, test_acc = model.evaluate(train_ds)
# Out:
# 544/544 ━━━━━━━━━━━━━━━━━━━━ 27s 49ms/step - accuracy: 0.9859 - loss: 0.0417

# %%
test_acc
# Out:
# 0.9859051704406738

# %%
for x, y in test_ds.take(1):
    print(x.shape)
# Out:
# (28, 64, 64, 3)

# %%
predictions = model.predict(x)
predicted_class = np.argmax(predictions, axis=1)
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 789ms/step

# %%
train_ds.class_names
# Out:
# ['asl_alphabet_train']

# %%
model_base = tf.keras.models.load_model('model_3.h5')
# Out:
# WARNING:absl:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.

# %%
# print(test_ds.class_names)
predictions = model_base.predict(test_ds)
np.argmax(predictions, axis=1)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[3], line 2
#       1 # print(test_ds.class_names)
# ----> 2 predictions = model_base.predict(test_ds)
#       3 np.argmax(predictions, axis=1)
#
# NameError: name 'test_ds' is not defined

# %%
for images, labels in test_ds.take(1):  # Take one batch from the dataset
    plt.figure(figsize=(10, 10))
    for i in range(len(images)):
        ax = plt.subplot(4, 4, i + 1)  # Adjust the grid size (4, 4) according to the number of images
        plt.imshow(images[i].numpy().astype("uint8"))
        plt.title(f"Label: {tf.argmax(labels[i]).numpy()}")  # Display the label if desired
        plt.axis("off")
    plt.show()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[14], line 4
#       2 plt.figure(figsize=(10, 10))
#       3 for i in range(len(images)):
# ----> 4     ax = plt.subplot(4, 4, i + 1)  # Adjust the grid size (4, 4) according to the number of images
#       5     plt.imshow(images[i].numpy().astype("uint8"))
#       6     plt.title(f"Label: {tf.argmax(labels[i]).numpy()}")  # Display the label if desired
#
# File c:\Anaconda\envs\ai\lib\site-packages\matplotlib\pyplot.py:1440, in subplot(*args, **kwargs)
#    1437 fig = gcf()
#    1439 # First, search for an existing subplot with a matching spec.
# -> 1440 key = SubplotSpec._from_subplot_args(fig, args)
#    1442 for ax in fig.axes:
#    1443     # If we found an Axes at the position, we can re-use it if the user passed no
#    1444     # kwargs or if the axes class and kwargs are identical.
# ...

# %%
list(train_ds.class_indices.keys())
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[31], line 1
# ----> 1 list(train_ds.class_indices.keys())
#
# AttributeError: '_PrefetchDataset' object has no attribute 'class_indices'
